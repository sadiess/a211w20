# %% [markdown]
# # ASTR 211 - HW02 - Sadie Seddon-Stettler

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from codes.plot_utils import plot_pretty, plot_line_points
plot_pretty(fontsize=12)

from codes.plot_utils import plot_line_points
from codes.plot_utils import plot_color_map
from codes.constants import clight

from codes.cosmology import d_L_romberg
from codes.cosmology import d_L_vectorized
from codes.cosmology import dl_func

from scipy import integrate
from scipy.interpolate import UnivariateSpline
from scipy.interpolate import RectBivariateSpline
from scipy.special import erf

# %%
k, Pk = np.loadtxt('data/test_matterpower_logintk1000.dat', usecols=(0, 1),  unpack=True)
lk, lPk = np.log10(k), np.log10(Pk)

# %% [markdown]
# ## Task 1a

# %%
def poly_approx(xtr, ftr, xt, method='interpolation', poly_order=1):
    ntr = np.size(ftr)
    
    if method == "interpolation":
        V = np.vander(xtr, N=ntr, increasing=True)
        a = np.linalg.solve(V, ftr)
    elif method == "regression":
        V = np.vander(xtr, N=poly_order, increasing=True)
        a = np.linalg.lstsq(V, ftr, rcond=None)[0]

    pfit = np.poly1d(a[::-1])
    ft = pfit(xt)
    
    return ft, a

# %%
xmin, xmax, ntr = 0., 2.*np.pi, 18
xtr = np.linspace(xmin, xmax, ntr)
ftr_int = np.sin(xtr)
# this vector is sine function + a little bit of Gaussian random noise (so mimics approximating noisy data)
ftr_fit = np.sin(xtr) + np.random.normal(scale=0.05, size=np.size(xtr))

nt = 1000 # should be different from nt
xt = np.linspace(xmin, xmax, nt)

poly_int, a_int = poly_approx(xtr, ftr_int, xt, method='interpolation')

poly_order=17
poly_fit, a_fit = poly_approx(xtr, ftr_fit, xt, method='regression', poly_order=poly_order)

# %%
plot_line_points(xt, poly_int, xp=xtr, yp=ftr_int, points=True,
                 xlabel=r'$x$', ylabel=r'$f(x)$', figsize=3)

# %%
plot_line_points(xt, poly_fit, xp=xtr, yp=ftr_fit, points=True,
                 xlabel=r'$x$', ylabel=r'$f(x)$', figsize=3)

# %% [markdown]
# 18 seems to be the smallest order of training points necessary to produce something that loosely resembles a sin function. This is due to the fact that the minimum number of training points necessary is N+1, where N is the order of the polynomial (and we are using a 17th order polynomial).

# %% [markdown]
# ## Task 1b

# %%
nkt = 1000
kt = np.linspace(k.min(), k.max(), nkt)
lkt = np.linspace(lk.min(), lk.max(), nkt)

# %%
poly_int, a_int = poly_approx(k, Pk, kt, method='interpolation', poly_order=np.size(kt))

# %%
print(a_int, np.size(a_int))
# Out:
# [nan nan nan ... nan nan nan] 3092

# %%
plot_line_points(kt, poly_int, xlabel=r'$x$', ylabel=r'$f(x)$', figsize=3)

# %% [markdown]
# When calculating the approximation via interpolation, we get a blank graph. This is due to the fact that interpolation requires us to go through every single point, but the P(k) function has such an intense spike that it would require a polynomial of immense magnitude to actually compute it - instead, the function fails and just generates nan valuse. But we can try again with log values, then with regression:

# %%
poly_int, a_int = poly_approx(lk, lPk, lkt, method='interpolation', poly_order=7)

# %%
plot_line_points(kt, poly_int, xlabel=r'$x$', ylabel=r'$f(x)$', figsize=4)

# %%
poly_int, a_int = poly_approx(lk, lPk, lkt, method='regression', poly_order=3)

# %%
plot_line_points(lkt, poly_int, xlabel=r'$x$', ylabel=r'$f(x)$', figsize=4)

# %% [markdown]
# This produces a much more sensible result. Again, the interpolation fails, but since regression does not require us to match exactly, we can produce something much closer to the actual function.
#
# A polynomial of order 7 matches very well. But in fact, we can go as low as 3 and still produce something somewhat sensible (with the maxima in the correct place at least). This probably works because the log10 of the function is very smooth and only has a single maxima, which means that low-order polynomials are actually capable of matching decently.

# %% [markdown]
# ## Task 1c

# %%
def cubic_spline_coefficients(xi, fi):
    """
    compute coefficients of the interpolating natural cubic spline
    see Appendix in the note for the derivation and details of the algorithm
    
    Parameters: 
        xi, fi: numpy float vectors
                tabulated points and function values
            
    Returns:
        a, b, c, d: numpy float vectors
                cubic spline coefficients 
                dx = x - xi[i]
                fx = a[i] + dx*(b[i] + c[i]*dx + d[i]*dx*dx)

    """
    delx = np.diff(xi); delf = np.diff(fi)
    # form matrices to solve for spline coefficients
    vx = np.zeros_like(xi)
    # form rhs vector using python's array slicing 
    vx[1:-1:] = 3.*(delf[1::]/delx[1::] - delf[:-1:]/delx[:-1:])
    # construct 3 diagonals
    nx = np.size(xi)
    diags = np.zeros((3, nx))
    diags[1,0] = 1.; diags[1,-1] = 1.
    diags[1,1:-1:] = 2. * (delx[1::] + delx[:-1:])
    diags[0,1:] = delx[:]
    diags[2,1:-1] = delx[1:]
    # solve for coefficients c using Thomas algorithm for tri-diagonal matrices
    # see https://www.cfd-online.com/Wiki/Tridiagonal_matrix_algorithm_-_TDMA_(Thomas_algorithm)
    ac, bc, cc, dc = map(np.array, (diags[0,:], diags[1,:], diags[2,:], vx)) # copy arrays
    for k in range(1, nx):
        mk = ac[k] / bc[k-1]
        bc[k] = bc[k] - mk * cc[k-1] 
        dc[k] = dc[k] - mk * dc[k-1]
    
    c = np.zeros_like(bc)
    c[-1] = dc[-1] / bc[-1]

    for k in range(nx-2, -1, -1):
        c[k] = (dc[k]-cc[k]*c[k+1])/bc[k]

    # now get the rest of the coefficients
    b = delf[::]/delx[::] - (c[1::] + 2.*c[:-1:])*delx[::]/3.
    d = (c[1::] - c[:-1:])/(3.*delx[::]) 
    a = fi
    return a, b, c, d

# %%
def cubic_spline(xt, xi, a, b, c, d):
    """
    piecewise linear approximation of f(x) given input of tabulated values of xi and fi
    note that xi are expected in ascending order
    
    Returns:
        vector of spline values at test points x 

    """
    n = np.size(xi) - 1
    fxt = np.empty_like(xt)
    fpxt = np.empty_like(xt)
    fppxt = np.empty_like(xt)
    fpppxt = np.empty_like(xt)
    fintxt = np.empty_like(xt)
    for j, x in enumerate(xt):
        for i in range(n):
            if (x >= xi[i]) and (x <= xi[i+1]):
                dx = x - xi[i]
                fxt[j] = a[i] + dx*(b[i] + c[i]*dx + d[i]*dx*dx)
                fpxt[j] = b[i] + dx*(2*c[i] + 3*d[i]*dx)
                fppxt[j] = (2*c[i]) + (6*d[i]*dx)
                fpppxt[j] = 6*d[i]
                fintxt = (a[i]*dx) + (0.5*b[i]*dx*dx) + ((1/3)*c[i]*dx*dx*dx) + (0.25*d[i]*dx*dx*dx*dx)
        
    return fxt, fpxt, fppxt, fpppxt, fintxt

# %%
xt = np.linspace(np.pi, 3*np.pi, 10)
xtest = np.linspace(np.pi, 3*np.pi, 100)
sinxt = np.sin(xt)

# %%
a, b, c, d = cubic_spline_coefficients(xt, sinxt)
spline_int, sinxp, sinxpp, sinxppp, sinxint = cubic_spline(xtest, xt, a, b, c, d)

# %%
plot_line_points(xtest, spline_int, 
                 xlabel=r'xt', ylabel=r'sin(xt)', figsize=3)

# %%
plot_line_points(xtest, sinxp, 
                 xlabel=r'xt', ylabel=r'$sin\prime(xt)$', figsize=3)

# %%
plot_line_points(xtest, sinxpp, 
                 xlabel=r'xt', ylabel=r'$sin\prime\prime(xt)$', figsize=3)

# %%
plot_line_points(xtest, sinxppp, 
                 xlabel=r'xt', ylabel=r'$sin\prime\prime\prime(xt)$', figsize=3)

# %%
sinxint
# Out:
# 0.22789875112773442

# %% [markdown]
# The cubic spline derivative at first looks completely correct, smooth and with minima/maxima in the correct places. However, moving to the second derivative makes the cubic spline really start to show - since the second derivative of a cubic function is linear, our second derivative is now made of chunks of linear functions. The third derivative of a cubic function is a constant, so our third derivative is a step function of constants. The integral is close to 0, but not quite - probably due to the large error in the third and second derivatives that are being used to calculate it. It approaches 0 as you increase the number of test points.

# %% [markdown]
# ## Task 1d

# %%
a, b, c, d = cubic_spline_coefficients(lk, lPk)
spline_int, lPkp, lPkpp, lPkppp, lPkint = cubic_spline(lkt, lk, a, b, c, d)

# %%
plot_line_points(lkt, lPkp, 
                 xlabel=r'\log_{10} k', ylabel=r'$\log_{10}P\prime(k)$', figsize=3)

# %% [markdown]
# ## Task 1e

# %%
spl = UnivariateSpline(lk, lPk, s=0.)
dspl = spl.derivative()

plot_line_points(lkt, dspl(lkt), xlabel=r'$\log_{10} k$', ylabel=r'$\log_{10}P(k)$', 
                 figsize=3)

# %%
spl = UnivariateSpline(lk, lPk, s=0.0001)
dspl = spl.derivative()

plot_line_points(lkt, dspl(lkt), xlabel=r'$\log_{10} k$', ylabel=r'$\log_{10}P(k)$', 
                 figsize=3)

# %%
spl = UnivariateSpline(lk, lPk, s=0.001)
dspl = spl.derivative()

plot_line_points(lkt, dspl(lkt), xlabel=r'$\log_{10} k$', ylabel=r'$\log_{10}P(k)$', 
                 figsize=3)

# %%
spl = UnivariateSpline(lk, lPk, s=0.01)
dspl = spl.derivative()

plot_line_points(lkt, dspl(lkt), xlabel=r'$\log_{10} k$', ylabel=r'$\log_{10}P(k)$', 
                 figsize=3)

# %% [markdown]
# As the value of s gets larger, the function gets smoother and smoother. Since s is the number of knots of the approximating spline, this makes sense - smaller values of s would be able to show greater granularity, and would show the small noise in the function with greater clarity.

# %% [markdown]
# ## Task 1f

# %%
xt = np.linspace(0, np.pi/2, 10)
sinxt = np.sin(xt)

spl = UnivariateSpline(sinxt, xt, s=0.)

print(spl(0), spl(0.5), spl(1))
print(np.arcsin(0), np.arcsin(0.5), np.arcsin(1))
# Out:
# 4.306270540770872e-19 0.5235987755982986 1.5707963267948966
# 0.0 0.5235987755982989 1.5707963267948966

# %% [markdown]
# Comparing the values of our inverse spline with the values returned by np.arcsin, we see that they are actually very close, to within machine precision (the first value is not 0.0 precisely, but it is to the order of e-19, which is 0 to machine precision.)

# %% [markdown]
# ## Task 2a

# %%
h0 = 70
z = 2.0
atol = 5.e-16; rtol = 5.e-16

# %%
def even_spacing(a, b, N):
    return np.linspace(a, b, N)
def chebyshev_nodes1(a, b, N):
    nodes = a + 0.5*(b-a)*(1. + np.cos((2.*np.arange(N+0)+1)*np.pi/(2.*(N+0))))
    nodes = nodes[::-1]
    return nodes
def chebyshev_nodes2(a, b, N):
    nodes = a + 0.5*(b-a)*(1. + np.cos(np.arange(N+0)*np.pi/N))
    nodes = nodes[::-1]
    return nodes

# %%
spacing = chebyshev_nodes1

ntrain = 15
ntest = 100

#training
Om0min, Om0max = 0., 1
OmLmin, OmLmax = 0., 1
Om0 = spacing(Om0min, Om0max, ntrain)
OmL = spacing(OmLmin, OmLmax, ntrain)
d_L_train = np.zeros((ntrain, ntrain))

#test
xt = spacing(Om0min, Om0max, ntest)
yt = spacing(Om0min, Om0max, ntest)
d_L_test = np.zeros((ntest, ntest))
xgt, ygt = np.meshgrid(xt, yt, sparse=False, indexing='ij')

for i, Omd in enumerate(Om0):
    for j, Omld in enumerate(OmL):
            Omk = 1.0 - Omd - Omld
            d_L_train[i][j] = h0 / clight * d_L_vectorized(z, h0, Omd, Omld, atol=atol, rtol=rtol)

for i, Omd in enumerate(xt):
    for j, Omld in enumerate(yt):
            Omk = 1.0 - Omd - Omld
            d_L_test[i][j] = h0 / clight * d_L_vectorized(z, h0, Omd, Omld, atol=atol, rtol=rtol)
# Out:
# C:\Users\sadie\Anaconda3\lib\site-packages\scipy\integrate\quadrature.py:802: AccuracyWarning: divmax (10) exceeded. Latest difference = 8.881784e-16
#   AccuracyWarning)
# C:\Users\sadie\Anaconda3\lib\site-packages\scipy\integrate\quadrature.py:802: AccuracyWarning: divmax (10) exceeded. Latest difference = 6.661338e-16
#   AccuracyWarning)
# C:\Users\sadie\Anaconda3\lib\site-packages\scipy\integrate\quadrature.py:802: AccuracyWarning: divmax (10) exceeded. Latest difference = 5.551115e-16
#   AccuracyWarning)

# %%
spl2d = RectBivariateSpline(Om0, OmL, d_L_train, s=0, kx=3, ky=3)
ft = spl2d(xt, yt)

# %%
plot_color_map(xgt, ygt, ft, xlim=[Om0min,Om0max], ylim=[OmLmin,OmLmax], 
                   xlabel = '$Om_0$', ylabel = '$Om_L$', cmap='plasma', colorbar=True, 
                   plot_title='$d_l$', 
                   figsize=5.0)

# %%
ferr = np.log10(np.abs(1-ft/d_L_test))

plot_color_map(xgt, ygt, ferr, xlim=[Om0min,Om0max], ylim=[OmLmin,OmLmax], 
                   xlabel = '$Om_0$', ylabel = '$Om_L$', cmap='plasma', colorbar=True, 
                   plot_title='$error$', 
                   figsize=5.0)
print(ferr.min(), ferr.max())
# Out:
# -11.021355641476195 -1.9325141702442152

# %% [markdown]
# ## Task 2b

# %%
def polyfit2d(xtr, ytr, ftr, kx=3, ky=3, order=None):
    '''
    Two dimensional polynomial fitting by least squares.
    Fits the functional form f(x,y) = z.

    Notes
    -----
    Resulting fit can be plotted with:
    np.polynomial.polynomial.polygrid2d(x, y, soln.reshape((kx+1, ky+1)))

    Parameters:
    ----------
    xtr, ytr: array-like, 1d
        xtr and ytr coordinates.
    ftr: 2d numpy array
        f(xgtr, ygtr) values evaluated on meshgrid of xtr and ytr vectors to fit by polynomial
    kx, ky: int, default is 3
        Polynomial order in x and y, respectively.
    order: int or None, default is None
        If None, all coefficients up to maxiumum kx, ky, ie. up to and including x^kx*y^ky, are considered.
        If int, coefficients up to a maximum of kx+ky <= order are considered.

    Returns:
    -------
    Return paramters from np.linalg.lstsq.

    soln: np.ndarray
        Array of polynomial coefficients.
    residuals: np.ndarray
    rank: int
    s: np.ndarray

    '''
    x, y = np.meshgrid(xtr, ytr)
    coeffs = np.ones((kx+1, ky+1))

    V = np.zeros((coeffs.size, x.size))

    for index, (j, i) in enumerate(np.ndindex(coeffs.shape)):
        if order is not None and i + j > order:
            arr = np.zeros_like(x)
        else:
            arr = coeffs[i, j] * x**i * y**j
        V[index] = arr.flatten()
        
    return np.linalg.lstsq(V.T, np.ravel(ftr), rcond=None)[0]

# %%
px, py = 10, 10

a = polyfit2d(Om0, OmL, d_L_train, kx=px, ky=py, order=None)
ff = np.polynomial.polynomial.polyval2d(xgt, ygt, a.reshape((px+1,py+1)))

# %%
plot_color_map(xgt, ygt, ff, xlim=[Om0min,Om0max], ylim=[OmLmin,OmLmax], 
                   xlabel = '$Om_0$', ylabel = '$Om_L$', cmap='plasma', colorbar=True, 
                   plot_title='$d_l$', 
                   figsize=5.0)

# %%
ferr = np.log10(np.abs(1-ff/d_L_test))
plot_color_map(xgt, ygt, ferr, xlim=[Om0min,Om0max], ylim=[OmLmin,OmLmax],
                   xlabel = '$Om_0$', ylabel = '$Om_L$', cmap='plasma', colorbar=True,
                   plot_title='$error$',
                   figsize=5.0)
print(ferr.min(), ferr.max())
# Out:
# -9.36452061478513 -3.4097598890071623

# %% [markdown]
# Through splitting up the work, we generated many plots and min/max errors for comparison. A fuller analysis of this is found in the powerpoint submitted alongside this notebook.
